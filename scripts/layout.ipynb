# %%
# notebook debugging preamble
# %load_ext autoreload
# %autoreload 2

# %%
from jianzipu.layout import parse_figma, get_all_layouts
from jianzipu.parser import parse

# %%
# from pprint import pp
from rich.pretty import pprint as pp

form_templates, layout_templates, component_dict = parse_figma()

# %%
all_layouts = get_all_layouts(form_templates, layout_templates, flatten=True)

# %%
pp(all_layouts)
# Out:
# [
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=571.13, y=507.07, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=460.08, y=671.3199999999999, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=378.38, y=574.52, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=424.69, y=589.86, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=464.51, y=536.49, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=424.09000000000003, y=668.58, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=353.34000000000003, y=528.36, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=380.27, y=683.9, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=479.0, y=668.62, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=440.9, y=691.85, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=583.15, y=641.51, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=390.32, y=752.69, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=571.13, y=507.07, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=460.08, y=671.3199999999999, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=378.38, y=574.52, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=424.69, y=589.86, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=464.51, y=536.49, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=424.09000000000003, y=668.58, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=353.34000000000003, y=528.36, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=380.27, y=683.9, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=479.0, y=668.62, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=440.9, y=691.85, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=583.15, y=641.51, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=390.32, y=752.69, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=571.13, y=507.07, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=460.08, y=671.3199999999999, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=378.38, y=574.52, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=424.69, y=589.86, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=464.51, y=536.49, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=424.09000000000003, y=668.58, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=353.34000000000003, y=528.36, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=380.27, y=683.9, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=479.0, y=668.62, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=440.9, y=691.85, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=583.15, y=641.51, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=180.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=390.32, y=752.69, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=467.13, y=507.07, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=356.08, y=671.3199999999999, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=274.38, y=574.52, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=320.69, y=589.86, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=360.51, y=536.49, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=320.09000000000003, y=668.58, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=249.34, y=528.36, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=276.27, y=683.9, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=375.0, y=668.62, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=336.9, y=691.85, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=479.15, y=641.51, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=217.0)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500.0, y=243.0, width=360.0, height=217.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=286.32, y=752.69, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=467.13, y=507.07, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=356.08, y=671.3199999999999, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=274.38, y=574.52, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=320.69, y=589.86, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=360.51, y=536.49, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=320.09000000000003, y=668.58, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=249.34, y=528.36, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=276.27, y=683.9, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=375.0, y=668.62, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=336.9, y=691.85, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=479.15, y=641.51, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500.0, y=25.0, width=360.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=286.32, y=752.69, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=467.13, y=507.07, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=356.08, y=671.3199999999999, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=274.38, y=574.52, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=320.69, y=589.86, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=360.51, y=536.49, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=320.09000000000003, y=668.58, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=249.34, y=528.36, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=276.27, y=683.9, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=375.0, y=668.62, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=336.9, y=691.85, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=479.15, y=641.51, width=360.0, height=435.0))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140.0, y=25.0, width=720.0, height=435.0)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=76.0, y=460.0, width=849.0, height=606.0)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=286.32, y=752.69, width=360.0, height=435.0))
# │   │   }
# │   )
# ]

# %%
pp(tree := parse("大九勾五", "abbr").flatten())
# Out:
# ParseNode(
# │   tag='SF',
# │   children={
# │   │   'hf': ParseNode(tag='hf', name='大'),
# │   │   'hn1': ParseNode(tag='hn1', name='九'),
# │   │   'xf': ParseNode(tag='xf', name='勾'),
# │   │   'xn1': ParseNode(tag='xn1', name='五')
# │   }
# )

# %%
pp(tree := parse("勾五", "abbr"))
# Out:
# ParseNode(
# │   tag='SF',
# │   children={
# │   │   'xfp': ParseNode(
# │   │   │   tag='xfp',
# │   │   │   children={'xf': ParseNode(tag='xf', name='勾'), 'xn1': ParseNode(tag='xn1', name='五')}
# │   │   )
# │   }
# )

# %%
pp(component_dict)
# Out:
# {
# │   'tuo1.md': Component(
# │   │   name='tuo1.md',
# │   │   area=Area(x=15.33, y=-33.67, width=814.8, height=678.96),
# │   │   container_area=Area(x=0.0, y=0.0, width=849.0, height=606.0),
# │   │   container_tag='xf'
# │   ),
# │   'pi1.md': Component(
# │   │   name='pi1.md',
# │   │   area=Area(x=59.32, y=-46.6, width=723.68, height=718.97),
# │   │   container_area=Area(x=0.0, y=0.0, width=849.0, height=606.0),
# │   │   container_tag='xf'
# │   ),
# │   'gou1.md': Component(
# │   │   name='gou1.md',
# │   │   area=Area(x=40.18, y=-66.49, width=736.67, height=760.3),
# │   │   container_area=Area(x=0.0, y=0.0, width=849.0, height=606.0),
# │   │   container_tag='xf'
# │   ),
# │   'ti1.md': Component(
# │   │   name='ti1.md',
# │   │   area=Area(x=73.0, y=-79.0, width=722.0, height=753.0),
# │   │   container_area=Area(x=0.0, y=0.0, width=849.0, height=606.0),
# │   │   container_tag='xf'
# │   ),
# │   'tiao3.md': Component(
# │   │   name='tiao3.md',
# │   │   area=Area(x=142.85, y=142.52, width=630.23, height=502.79),
# │   │   container_area=Area(x=0.0, y=0.0, width=849.0, height=606.0),
# │   │   container_tag='xf'
# │   ),
# │   'mo3.md': Component(
# │   │   name='mo3.md',
# │   │   area=Area(x=42.91, y=-49.47, width=768.35, height=331.27),
# │   │   container_area=Area(x=0.0, y=0.0, width=849.0, height=606.0),
# │   │   container_tag='xf'
# │   ),
# │   'da3.md': Component(
# │   │   name='da3.md',
# │   │   area=Area(x=74.29, y=-75.12, width=703.55, height=758.91),
# │   │   container_area=Area(x=0.0, y=0.0, width=849.0, height=606.0),
# │   │   container_tag='xf'
# │   ),
# │   'zhai1.md': Component(
# │   │   name='zhai1.md',
# │   │   area=Area(x=79.64, y=-101.34, width=684.02, height=835.66),
# │   │   container_area=Area(x=0.0, y=0.0, width=849.0, height=606.0),
# │   │   container_tag='xf'
# │   ),
# │   'mo3tiao3.md': Component(
# │   │   name='mo3tiao3.md',
# │   │   area=Area(x=41.0, y=-58.0, width=768.35, height=796.83),
# │   │   container_area=Area(x=0.0, y=0.0, width=849.0, height=606.0),
# │   │   container_tag='xf'
# │   ),
# │   'gou1ti1.md': Component(
# │   │   name='gou1ti1.md',
# │   │   area=Area(x=0.0, y=-74.0, width=850.01, height=823.32),
# │   │   container_area=Area(x=0.0, y=0.0, width=849.0, height=606.0),
# │   │   container_tag='xf'
# │   ),
# │   'tuo1pi1.md': Component(
# │   │   name='tuo1pi1.md',
# │   │   area=Area(x=4.13, y=-50.68, width=820.49, height=789.69),
# │   │   container_area=Area(x=0.0, y=0.0, width=849.0, height=606.0),
# │   │   container_tag='xf'
# │   ),
# │   'da3zhai1.md': Component(
# │   │   name='da3zhai1.md',
# │   │   area=Area(x=106.22, y=-72.3, width=654.79, height=814.67),
# │   │   container_area=Area(x=0.0, y=0.0, width=849.0, height=606.0),
# │   │   container_tag='xf'
# │   )
# }
