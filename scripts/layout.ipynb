# %% [markdown]
# # 布局用法一览 Layout class showcase

# %%
# notebook debugging preamble
# %load_ext autoreload
# %autoreload 2

# %%
from jianzipu.layout import parse_figma, get_all_layouts
from jianzipu.parser import parse

# %%
# from pprint import pp
from rich.pretty import pprint as pp

form_templates, layout_templates, component_dict = parse_figma()

# %%
all_layouts = get_all_layouts(form_templates, layout_templates, flatten=False)

# %%
pp(all_layouts)
# Out:
# [
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=391, y=47, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=280, y=211, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=198, y=115, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=245, y=130, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=285, y=76, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=244, y=209, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=173, y=68, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=200, y=224, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=299, y=209, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=261, y=232, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=403, y=182, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=210, y=293, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=391, y=47, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=280, y=211, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=198, y=115, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=245, y=130, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=285, y=76, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=244, y=209, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=173, y=68, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=200, y=224, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=299, y=209, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=261, y=232, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=403, y=182, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=210, y=293, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=391, y=47, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=280, y=211, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=198, y=115, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=245, y=130, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=285, y=76, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=244, y=209, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=173, y=68, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=200, y=224, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=299, y=209, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=261, y=232, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=403, y=182, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=180, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=210, y=293, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=391, y=47, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=280, y=211, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=198, y=115, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=245, y=130, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=285, y=76, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=244, y=209, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=173, y=68, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=200, y=224, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=299, y=209, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=261, y=232, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=403, y=182, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=210, y=293, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=391, y=47, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=280, y=211, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# ...
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=245, y=130, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=285, y=76, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=244, y=209, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=173, y=68, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=200, y=224, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=299, y=209, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=261, y=232, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=403, y=182, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={
# │   │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   │   }
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=210, y=293, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=391, y=47, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=280, y=211, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=198, y=115, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=245, y=130, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=285, y=76, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=244, y=209, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=173, y=68, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=200, y=224, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=299, y=209, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=261, y=232, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=403, y=182, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hfp': LayoutNode(
# │   │   │   │   tag='hfp',
# │   │   │   │   area=Area(x=140, y=25, width=720, height=435),
# │   │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   │   ),
# │   │   │   'xfp': LayoutNode(
# │   │   │   │   tag='xfp',
# │   │   │   │   area=Area(x=76, y=460, width=849, height=606),
# │   │   │   │   children={
# │   │   │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=210, y=293, width=360, height=435))
# │   │   │   │   }
# │   │   │   )
# │   │   }
# │   )
# ]

# %%
pp(tree := parse("大九勾五", "abbr").flatten())
# Out:
# ParseNode(
# │   tag='SF',
# │   children={
# │   │   'hf': ParseNode(tag='hf', name='大'),
# │   │   'hn1': ParseNode(tag='hn1', name='九'),
# │   │   'xf': ParseNode(tag='xf', name='勾'),
# │   │   'xn1': ParseNode(tag='xn1', name='五')
# │   }
# )

# %%
pp(tree := parse("勾五", "abbr"))
# Out:
# ParseNode(
# │   tag='SF',
# │   children={
# │   │   'xfp': ParseNode(
# │   │   │   tag='xfp',
# │   │   │   children={'xf': ParseNode(tag='xf', name='勾'), 'xn1': ParseNode(tag='xn1', name='五')}
# │   │   )
# │   }
# )

# %%
pp(component_dict)
# Out:
# {
# │   'tuo1.md': Component(
# │   │   name='tuo1.md',
# │   │   area=Area(x=15, y=-34, width=815, height=679),
# │   │   container_area=Area(x=0, y=0, width=849, height=606),
# │   │   container_tag='xf'
# │   ),
# │   'pi1.md': Component(
# │   │   name='pi1.md',
# │   │   area=Area(x=59, y=-47, width=724, height=719),
# │   │   container_area=Area(x=0, y=0, width=849, height=606),
# │   │   container_tag='xf'
# │   ),
# │   'mo3.md': Component(
# │   │   name='mo3.md',
# │   │   area=Area(x=43, y=-49, width=768, height=331),
# │   │   container_area=Area(x=0, y=0, width=849, height=606),
# │   │   container_tag='xf'
# │   ),
# │   'tiao3.md': Component(
# │   │   name='tiao3.md',
# │   │   area=Area(x=143, y=143, width=630, height=503),
# │   │   container_area=Area(x=0, y=0, width=849, height=606),
# │   │   container_tag='xf'
# │   ),
# │   'gou1.md': Component(
# │   │   name='gou1.md',
# │   │   area=Area(x=40, y=-66, width=737, height=760),
# │   │   container_area=Area(x=0, y=0, width=849, height=606),
# │   │   container_tag='xf'
# │   ),
# │   'ti1.md': Component(
# │   │   name='ti1.md',
# │   │   area=Area(x=73, y=-79, width=722, height=753),
# │   │   container_area=Area(x=0, y=0, width=849, height=606),
# │   │   container_tag='xf'
# │   ),
# │   'da3.md': Component(
# │   │   name='da3.md',
# │   │   area=Area(x=74, y=-75, width=704, height=759),
# │   │   container_area=Area(x=0, y=0, width=849, height=606),
# │   │   container_tag='xf'
# │   ),
# │   'zhai1.md': Component(
# │   │   name='zhai1.md',
# │   │   area=Area(x=80, y=-101, width=684, height=836),
# │   │   container_area=Area(x=0, y=0, width=849, height=606),
# │   │   container_tag='xf'
# │   ),
# │   'tuo1pi1.md': Component(
# │   │   name='tuo1pi1.md',
# │   │   area=Area(x=4, y=-51, width=820, height=790),
# │   │   container_area=Area(x=0, y=0, width=849, height=606),
# │   │   container_tag='xf'
# │   ),
# │   'mo3tiao3.md': Component(
# │   │   name='mo3tiao3.md',
# │   │   area=Area(x=41, y=-58, width=768, height=797),
# │   │   container_area=Area(x=0, y=0, width=849, height=606),
# │   │   container_tag='xf'
# │   ),
# │   'gou1ti1.md': Component(
# │   │   name='gou1ti1.md',
# │   │   area=Area(x=0, y=-74, width=850, height=823),
# │   │   container_area=Area(x=0, y=0, width=849, height=606),
# │   │   container_tag='xf'
# │   ),
# │   'da3zhai1.md': Component(
# │   │   name='da3zhai1.md',
# │   │   area=Area(x=106, y=-72, width=655, height=815),
# │   │   container_area=Area(x=0, y=0, width=849, height=606),
# │   │   container_tag='xf'
# │   ),
# │   'yi1.md': Component(
# │   │   name='yi1.md',
# │   │   area=Area(x=-36, y=141, width=431, height=76),
# │   │   container_area=Area(x=0, y=0, width=360, height=435),
# │   │   container_tag='n'
# │   ),
# │   'er4.md': Component(
# │   │   name='er4.md',
# │   │   area=Area(x=-32, y=59, width=424, height=317),
# │   │   container_area=Area(x=0, y=0, width=360, height=435),
# │   │   container_tag='n'
# │   ),
# │   'san1.md': Component(
# │   │   name='san1.md',
# │   │   area=Area(x=-37, y=32, width=433, height=371),
# │   │   container_area=Area(x=0, y=0, width=360, height=435),
# │   │   container_tag='n'
# │   ),
# │   'si4.md': Component(
# │   │   name='si4.md',
# │   │   area=Area(x=-14, y=27, width=387, height=408),
# │   │   container_area=Area(x=0, y=0, width=360, height=435),
# │   │   container_tag='n'
# │   ),
# │   'wu3.md': Component(
# │   │   name='wu3.md',
# │   │   area=Area(x=-38, y=26, width=436, height=383),
# │   │   container_area=Area(x=0, y=0, width=360, height=435),
# │   │   container_tag='n'
# │   ),
# │   'liu4.md': Component(
# │   │   name='liu4.md',
# │   │   area=Area(x=-35, y=10, width=430, height=415),
# │   │   container_area=Area(x=0, y=0, width=360, height=435),
# │   │   container_tag='n'
# │   ),
# │   'qi1.md': Component(
# │   │   name='qi1.md',
# │   │   area=Area(x=-37, y=16, width=434, height=403),
# │   │   container_area=Area(x=0, y=0, width=360, height=435),
# │   │   container_tag='n'
# │   ),
# │   'ba1.md': Component(
# │   │   name='ba1.md',
# │   │   area=Area(x=-37, y=7, width=434, height=420),
# │   │   container_area=Area(x=0, y=0, width=360, height=435),
# │   │   container_tag='n'
# │   ),
# │   'jiu3.md': Component(
# │   │   name='jiu3.md',
# │   │   area=Area(x=-35, y=4, width=430, height=427),
# │   │   container_area=Area(x=0, y=0, width=360, height=435),
# │   │   container_tag='n'
# │   ),
# │   'shii2.md': Component(
# │   │   name='shii2.md',
# │   │   area=Area(x=-35, y=4, width=430, height=427),
# │   │   container_area=Area(x=0, y=0, width=360, height=435),
# │   │   container_tag='n'
# │   ),
# │   'shi2yi1.md': Component(
# │   │   name='shi2yi1.md',
# │   │   area=Area(x=-35, y=4, width=430, height=426),
# │   │   container_area=Area(x=0, y=0, width=360, height=435),
# │   │   container_tag='n'
# │   ),
# │   'shi2er4.md': Component(
# │   │   name='shi2er4.md',
# │   │   area=Area(x=-35, y=4, width=430, height=426),
# │   │   container_area=Area(x=0, y=0, width=360, height=435),
# │   │   container_tag='n'
# │   ),
# │   'shi2san1.md': Component(
# │   │   name='shi2san1.md',
# │   │   area=Area(x=-36, y=4, width=432, height=426),
# │   │   container_area=Area(x=0, y=0, width=360, height=435),
# │   │   container_tag='n'
# │   ),
# │   'wai4.md': Component(
# │   │   name='wai4.md',
# │   │   area=Area(x=82, y=2, width=267, height=431),
# │   │   container_area=Area(x=0, y=0, width=360, height=435),
# │   │   container_tag='n'
# │   ),
# │   'ban4.md': Component(
# │   │   name='ban4.md',
# │   │   area=Area(x=-35, y=3, width=429, height=430),
# │   │   container_area=Area(x=0, y=0, width=360, height=435),
# │   │   container_tag='n'
# │   )
# }
