# %%
# notebook debugging preamble
# %load_ext autoreload
# %autoreload 2

# %%
from jianzipu.layout import parse_figma, get_all_layouts

# %%
from pprint import pp

form_templates, layout_templates, component_dict = parse_figma()

# %%
all_layouts = get_all_layouts(form_templates, layout_templates, flatten=True)

# %%
pp(form_templates["SF"][0])
# Out:
# LayoutNode(tag='SF',
#            name='',
#            area=Area(x=0, y=0, width=0, height=0),
#            children={'hfp': LayoutNode(tag='hfp',
#                                        name='',
#                                        area=Area(x=140.0,
#                                                  y=25.0,
#                                                  width=720.0,
#                                                  height=435.0),
#                                        children={}),
#                      'xfp': LayoutNode(tag='xfp',
#                                        name='',
#                                        area=Area(x=180.0,
#                                                  y=460.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={})})

# %%
pp(all_layouts)
# Out:
# [LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'hn2': LayoutNode(tag='hn2',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=218.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='托',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=391.13,
#                                                   y=47.07,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'hn2': LayoutNode(tag='hn2',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=218.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='擘',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=280.08,
#                                                   y=211.32,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'hn2': LayoutNode(tag='hn2',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=218.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='勾',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=198.38,
#                                                   y=114.52,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'hn2': LayoutNode(tag='hn2',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=218.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='剔',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=244.69,
#                                                   y=129.86,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'hn2': LayoutNode(tag='hn2',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=218.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='挑',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=284.51,
#                                                   y=76.49,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'hn2': LayoutNode(tag='hn2',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=218.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='抹',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=244.09,
#                                                   y=208.58,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'hn2': LayoutNode(tag='hn2',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=218.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='打',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=173.34,
#                                                   y=68.36,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'hn2': LayoutNode(tag='hn2',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=218.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='摘',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=200.27,
#                                                   y=223.9,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'hn2': LayoutNode(tag='hn2',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=218.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='抹挑',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=299.0,
#                                                   y=208.62,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'hn2': LayoutNode(tag='hn2',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=218.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='勾剔',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=260.9,
#                                                   y=231.85,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'hn2': LayoutNode(tag='hn2',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=218.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='托擘',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=403.15,
#                                                   y=181.51,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'hn2': LayoutNode(tag='hn2',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=218.0,
#                                                   width=360.0,
#                                                   height=217.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='打摘',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=210.32,
#                                                   y=292.69,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='托',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=391.13,
#                                                   y=47.07,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='擘',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=280.08,
#                                                   y=211.32,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='勾',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=198.38,
#                                                   y=114.52,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='剔',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=244.69,
#                                                   y=129.86,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='挑',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=284.51,
#                                                   y=76.49,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='抹',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=244.09,
#                                                   y=208.58,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='打',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=173.34,
#                                                   y=68.36,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='摘',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=200.27,
#                                                   y=223.9,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='抹挑',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=299.0,
#                                                   y=208.62,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='勾剔',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=260.9,
#                                                   y=231.85,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='托擘',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=403.15,
#                                                   y=181.51,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=360.0,
#                                                  height=435.0),
#                                        children={}),
#                       'hn1': LayoutNode(tag='hn1',
#                                         name='',
#                                         area=Area(x=360.0,
#                                                   y=0.0,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='打摘',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=210.32,
#                                                   y=292.69,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=720.0,
#                                                  height=435.0),
#                                        children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='托',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=391.13,
#                                                   y=47.07,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=720.0,
#                                                  height=435.0),
#                                        children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='擘',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=280.08,
#                                                   y=211.32,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=720.0,
#                                                  height=435.0),
# ...
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=210.32,
#                                                   y=292.69,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=720.0,
#                                                  height=435.0),
#                                        children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='托',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=391.13,
#                                                   y=47.07,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=720.0,
#                                                  height=435.0),
#                                        children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='擘',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=280.08,
#                                                   y=211.32,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=720.0,
#                                                  height=435.0),
#                                        children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='勾',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=198.38,
#                                                   y=114.52,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=720.0,
#                                                  height=435.0),
#                                        children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='剔',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=244.69,
#                                                   y=129.86,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=720.0,
#                                                  height=435.0),
#                                        children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='挑',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=284.51,
#                                                   y=76.49,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=720.0,
#                                                  height=435.0),
#                                        children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='抹',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=244.09,
#                                                   y=208.58,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=720.0,
#                                                  height=435.0),
#                                        children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='打',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=173.34,
#                                                   y=68.36,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=720.0,
#                                                  height=435.0),
#                                        children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='摘',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=200.27,
#                                                   y=223.9,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=720.0,
#                                                  height=435.0),
#                                        children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='抹挑',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=299.0,
#                                                   y=208.62,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=720.0,
#                                                  height=435.0),
#                                        children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='勾剔',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=260.9,
#                                                   y=231.85,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=720.0,
#                                                  height=435.0),
#                                        children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='托擘',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=403.15,
#                                                   y=181.51,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})}),
#  LayoutNode(tag='SF',
#             name='',
#             area=Area(x=0, y=0, width=0, height=0),
#             children={'hf': LayoutNode(tag='hf',
#                                        name='',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=720.0,
#                                                  height=435.0),
#                                        children={}),
#                       'xf': LayoutNode(tag='xf',
#                                        name='打摘',
#                                        area=Area(x=0.0,
#                                                  y=0.0,
#                                                  width=849.0,
#                                                  height=606.0),
#                                        children={}),
#                       'xn1': LayoutNode(tag='xn1',
#                                         name='',
#                                         area=Area(x=210.32,
#                                                   y=292.69,
#                                                   width=360.0,
#                                                   height=435.0),
#                                         children={})})]
