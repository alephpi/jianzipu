# %%
# notebook debugging preamble
# %load_ext autoreload
# %autoreload 2

# %%
from jianzipu.layout import parse_figma

form_templates, layout_templates, component_dict = parse_figma()

# %%
component_dict["tuo1.md"].xywh
# Out:
# (15.33, -33.67, 814.8, 678.96)

# %%
from jianzipu.constants import GLYPHS

GLYPHS.GlyphName.tolist()
# Out:
# ['san3',
#  'da4',
#  'shi2',
#  'zhong1',
#  'ming2',
#  'gui4',
#  'tuo1',
#  'pi1',
#  'mo3',
#  'tiao3',
#  'gou1',
#  'ti1',
#  'da3',
#  'zhai1',
#  'tuo1pi1',
#  'mo3tiao3',
#  'gou1ti1',
#  'da3zhai1',
#  'li4',
#  'juan1',
#  'lun2',
#  'ban4lun2',
#  'suo3',
#  'chang2suo3',
#  'ru2yi1',
#  'fu2',
#  'ru2yi1sheng1',
#  'gun3',
#  'fo2',
#  'zhi4',
#  'gun3fo2',
#  'quan2fu2',
#  'bo1',
#  'la4',
#  'la4fu2',
#  'da3yuan2',
#  'tao1qi3',
#  'zhua1qi3',
#  'dai4qi3',
#  'yan3',
#  'xu1yan3',
#  'tui1chu1',
#  'bu4dong4',
#  'shang4',
#  'xia4',
#  'jin4',
#  'tui4',
#  'fu4',
#  'jin4fu4',
#  'tui4fu4',
#  'wang3lai2',
#  'zhuang4',
#  'dou4',
#  'huan4',
#  'yin2',
#  'nao2',
#  'zhu4',
#  'chuo4',
#  'yin3',
#  'tang3',
#  'ji2',
#  'huan3',
#  'jin3',
#  'man4',
#  'fen1kai1',
#  'tong2sheng1',
#  'ying4he2',
#  'fang4he2',
#  'qia1cuo1san1sheng1',
#  'cuo1',
#  'qia1cuo1',
#  'shuang1dan4',
#  'bo1la4',
#  'qi2cuo1',
#  'shao3xi1',
#  'da4xi1',
#  'ru4pai1',
# ...
