# %%
# notebook debugging preamble
# %load_ext autoreload
# %autoreload 2

# %%
from jianzipu.parser import parse
from jianzipu.layout import parse_figma, get_all_layouts
from jianzipu.feature import (
    find_matching_layout,
    write_pos_rule,
)

# %%
# from pprint import pp
from rich.pretty import pprint as pp

form_templates, layout_templates, component_dict = parse_figma()

# %%
pp(layout_templates["hfp"])
# Out:
# [
# │   LayoutNode(
# │   │   tag='hfp',
# │   │   area=Area(x=0, y=0, width=720, height=435),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='hfp',
# │   │   area=Area(x=0, y=0, width=720, height=435),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='hfp',
# │   │   area=Area(x=0, y=0, width=720, height=435),
# │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   ),
# │   LayoutNode(
# │   │   tag='hfp',
# │   │   area=Area(x=0, y=0, width=720, height=435),
# │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435))}
# │   )
# ]

# %%
pp(form_templates)
# Out:
# {
# │   'SF': [
# │   │   LayoutNode(
# │   │   │   tag='SF',
# │   │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   │   children={
# │   │   │   │   'hfp': LayoutNode(tag='hfp', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   │   'xfp': LayoutNode(tag='xfp', area=Area(x=180, y=460, width=849, height=606))
# │   │   │   }
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='SF',
# │   │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   │   children={
# │   │   │   │   'hfp': LayoutNode(tag='hfp', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   │   'xfp': LayoutNode(tag='xfp', area=Area(x=76, y=460, width=849, height=606))
# │   │   │   }
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='SF',
# │   │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   │   children={
# │   │   │   │   'hfp': LayoutNode(tag='hfp', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606))
# │   │   │   }
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='SF',
# │   │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   │   children={
# │   │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   │   'xfp': LayoutNode(tag='xfp', area=Area(x=180, y=460, width=849, height=606))
# │   │   │   }
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='SF',
# │   │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   │   children={'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606))}
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='SF',
# │   │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   │   children={'hfp': LayoutNode(tag='hfp', area=Area(x=140, y=25, width=720, height=435))}
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='SF',
# │   │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   │   children={'xfp': LayoutNode(tag='xfp', area=Area(x=76, y=460, width=849, height=606))}
# │   │   )
# │   ]
# }

# %%
pp(layout_templates)
# Out:
# defaultdict(<class 'list'>, {
# │   'xfp': [
# │   │   LayoutNode(
# │   │   │   tag='xfp',
# │   │   │   area=Area(x=0, y=0, width=849, height=606),
# │   │   │   children={
# │   │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=391, y=47, width=360, height=435))
# │   │   │   }
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='xfp',
# │   │   │   area=Area(x=0, y=0, width=849, height=606),
# │   │   │   children={
# │   │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=280, y=211, width=360, height=435))
# │   │   │   }
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='xfp',
# │   │   │   area=Area(x=0, y=0, width=849, height=606),
# │   │   │   children={
# │   │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=198, y=115, width=360, height=435))
# │   │   │   }
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='xfp',
# │   │   │   area=Area(x=0, y=0, width=849, height=606),
# │   │   │   children={
# │   │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=245, y=130, width=360, height=435))
# │   │   │   }
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='xfp',
# │   │   │   area=Area(x=0, y=0, width=849, height=606),
# │   │   │   children={
# │   │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=285, y=76, width=360, height=435))
# │   │   │   }
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='xfp',
# │   │   │   area=Area(x=0, y=0, width=849, height=606),
# │   │   │   children={
# │   │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=244, y=209, width=360, height=435))
# │   │   │   }
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='xfp',
# │   │   │   area=Area(x=0, y=0, width=849, height=606),
# │   │   │   children={
# │   │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=173, y=68, width=360, height=435))
# │   │   │   }
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='xfp',
# │   │   │   area=Area(x=0, y=0, width=849, height=606),
# │   │   │   children={
# │   │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=200, y=224, width=360, height=435))
# │   │   │   }
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='xfp',
# │   │   │   area=Area(x=0, y=0, width=849, height=606),
# │   │   │   children={
# │   │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=299, y=209, width=360, height=435))
# │   │   │   }
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='xfp',
# │   │   │   area=Area(x=0, y=0, width=849, height=606),
# │   │   │   children={
# │   │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=261, y=232, width=360, height=435))
# │   │   │   }
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='xfp',
# │   │   │   area=Area(x=0, y=0, width=849, height=606),
# │   │   │   children={
# │   │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=403, y=182, width=360, height=435))
# │   │   │   }
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='xfp',
# │   │   │   area=Area(x=0, y=0, width=849, height=606),
# │   │   │   children={
# │   │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=0, y=0, width=849, height=606)),
# │   │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=210, y=293, width=360, height=435))
# │   │   │   }
# │   │   )
# │   ],
# │   'hfp': [
# │   │   LayoutNode(
# │   │   │   tag='hfp',
# │   │   │   area=Area(x=0, y=0, width=720, height=435),
# │   │   │   children={
# │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=217)),
# │   │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=360, y=218, width=360, height=217))
# │   │   │   }
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='hfp',
# │   │   │   area=Area(x=0, y=0, width=720, height=435),
# │   │   │   children={
# │   │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=360, height=435)),
# │   │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=360, y=0, width=360, height=435))
# │   │   │   }
# │   │   ),
# │   │   LayoutNode(
# │   │   │   tag='hfp',
# │   │   │   area=Area(x=0, y=0, width=720, height=435),
# │   │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=0, y=0, width=720, height=435))}
# │   │   )
# │   ],
# │   'hf': [
# │   │   LayoutNode(tag='hf', name='大', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='hf', name='名', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='hf', name='跪', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='hf', name='食', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='hf', name='中', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='hf', name='散', area=Area(x=0, y=0, width=720, height=435))
# │   ],
# │   'n': [
# │   │   LayoutNode(tag='n', name='半', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='n', name='外', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='n', name='十', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='n', name='九', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='n', name='八', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='n', name='七', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='n', name='六', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='n', name='五', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='n', name='四', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='n', name='三', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='n', name='二', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='n', name='十三', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='n', name='十二', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='n', name='十一', area=Area(x=0, y=0, width=360, height=435)),
# │   │   LayoutNode(tag='n', name='一', area=Area(x=0, y=0, width=360, height=435))
# │   ]
# })

# %%
all_layouts = get_all_layouts(form_templates, layout_templates, flatten=True)

# %%
pp(all_layouts)
# Out:
# [
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=571, y=507, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=460, y=671, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=378, y=575, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=425, y=590, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=465, y=536, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=424, y=669, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=353, y=528, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=380, y=684, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=479, y=669, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=441, y=692, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=583, y=642, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=390, y=753, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=571, y=507, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=460, y=671, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=378, y=575, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=425, y=590, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=465, y=536, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=424, y=669, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=353, y=528, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=380, y=684, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=479, y=669, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=441, y=692, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=583, y=642, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=390, y=753, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=571, y=507, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=460, y=671, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=378, y=575, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=425, y=590, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=465, y=536, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=424, y=669, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=353, y=528, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=380, y=684, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=479, y=669, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=441, y=692, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=583, y=642, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=390, y=753, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=467, y=507, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=356, y=671, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=274, y=575, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=321, y=590, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=361, y=536, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=320, y=669, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=249, y=528, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=276, y=684, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=375, y=669, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=337, y=692, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=479, y=642, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=286, y=753, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=467, y=507, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=356, y=671, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=274, y=575, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=321, y=590, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=361, y=536, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=320, y=669, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=249, y=528, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=276, y=684, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=375, y=669, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=337, y=692, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=479, y=642, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=286, y=753, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=467, y=507, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=356, y=671, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=274, y=575, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=321, y=590, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=361, y=536, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=320, y=669, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=249, y=528, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=276, y=684, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=375, y=669, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=337, y=692, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=479, y=642, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=286, y=753, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435)),
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=571, y=507, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=460, y=671, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=378, y=575, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=425, y=590, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=465, y=536, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=424, y=669, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=353, y=528, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=380, y=684, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=479, y=669, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=441, y=692, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=583, y=642, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=180, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=390, y=753, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606))}
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=720, height=435))}
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=467, y=507, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'xf': LayoutNode(tag='xf', name='擘', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=356, y=671, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'xf': LayoutNode(tag='xf', name='勾', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=274, y=575, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'xf': LayoutNode(tag='xf', name='剔', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=321, y=590, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'xf': LayoutNode(tag='xf', name='挑', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=361, y=536, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'xf': LayoutNode(tag='xf', name='抹', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=320, y=669, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'xf': LayoutNode(tag='xf', name='打', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=249, y=528, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'xf': LayoutNode(tag='xf', name='摘', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=276, y=684, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'xf': LayoutNode(tag='xf', name='抹挑', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=375, y=669, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'xf': LayoutNode(tag='xf', name='勾剔', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=337, y=692, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'xf': LayoutNode(tag='xf', name='托擘', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=479, y=642, width=360, height=435))
# │   │   }
# │   ),
# │   LayoutNode(
# │   │   tag='SF',
# │   │   area=Area(x=0, y=0, width=1000, height=1000),
# │   │   children={
# │   │   │   'xf': LayoutNode(tag='xf', name='打摘', area=Area(x=76, y=460, width=849, height=606)),
# │   │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=286, y=753, width=360, height=435))
# │   │   }
# │   )
# ]

# %%
parse_tree = parse("大九托三")

# %%
pp(parse_tree)
# Out:
# ParseNode(
# │   tag='SF',
# │   children={
# │   │   'hfp': ParseNode(
# │   │   │   tag='hfp',
# │   │   │   children={'hf': ParseNode(tag='hf', name='大'), 'hn1': ParseNode(tag='hn1', name='九')}
# │   │   ),
# │   │   'xfp': ParseNode(
# │   │   │   tag='xfp',
# │   │   │   children={'xf': ParseNode(tag='xf', name='托'), 'xn1': ParseNode(tag='xn1', name='三')}
# │   │   )
# │   }
# )

# %%
parse_tree = parse("大九托三").flatten()

# %%
pp(parse_tree)
# Out:
# ParseNode(
# │   tag='SF',
# │   children={
# │   │   'hf': ParseNode(tag='hf', name='大'),
# │   │   'hn1': ParseNode(tag='hn1', name='九'),
# │   │   'xf': ParseNode(tag='xf', name='托'),
# │   │   'xn1': ParseNode(tag='xn1', name='三')
# │   }
# )

# %%
puzi_tags = parse_tree.children.keys()

# %%
pp(all_layouts[0])
# Out:
# LayoutNode(
# │   tag='SF',
# │   area=Area(x=0, y=0, width=1000, height=1000),
# │   children={
# │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=217)),
# │   │   'hn2': LayoutNode(tag='hn2', area=Area(x=500, y=243, width=360, height=217)),
# │   │   'sf': LayoutNode(tag='sf', area=Area(x=24, y=460, width=234, height=606)),
# │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=180, y=460, width=849, height=606)),
# │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=571, y=507, width=360, height=435))
# │   }
# )

# %%
matched_layout = find_matching_layout(parse_tree, all_layouts)

pp(matched_layout)
# Out:
# LayoutNode(
# │   tag='SF',
# │   area=Area(x=0, y=0, width=1000, height=1000),
# │   children={
# │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=76, y=460, width=849, height=606)),
# │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=467, y=507, width=360, height=435))
# │   }
# )

# %%
macros, rule_templates = import_macros()
write_fea(macros, rule_templates)

# %%
rule_templates
# Out:
# {('hf', 'xf', 'xn1'): ['@hf_lg', '@xf_md', '@xn_md', '@xn_md'],
#  ('hf', 'hn1', 'xf', 'xn1'): ['@hf_md', '@hn_md', '@xf_md', '@xn_md'],
#  ('hf', 'hn1', 'hn2', 'xf', 'xn1'): ['@hf_md',
#   '@hn_sm',
#   '@hn_sm',
#   '@xf_md',
#   '@xn_md'],
#  ('hf', 'sf', 'xf', 'xn1'): ['@hf_lg', '@sf_md', '@xf_md', '@xn_md', '@xn_md'],
#  ('hf', 'hn1', 'sf', 'xf', 'xn1'): ['@hf_md',
#   '@hn_md',
#   '@sf_md',
#   '@xf_md',
#   '@xn_md'],
#  ('hf', 'hn1', 'hn2', 'sf', 'xf', 'xn1'): ['@hf_md',
#   '@hn_sm',
#   '@hn_sm',
#   '@sf_md',
#   '@xf_md',
#   '@xn_md']}

# %%
len(all_layouts)
# Out:
# 72

# %%
pp(matched_layout)
# Out:
# LayoutNode(
# │   tag='SF',
# │   area=Area(x=0, y=0, width=1000, height=1000),
# │   children={
# │   │   'hf': LayoutNode(tag='hf', area=Area(x=140, y=25, width=360, height=435)),
# │   │   'hn1': LayoutNode(tag='hn1', area=Area(x=500, y=25, width=360, height=435)),
# │   │   'xf': LayoutNode(tag='xf', name='托', area=Area(x=76, y=460, width=849, height=606)),
# │   │   'xn1': LayoutNode(tag='xn1', area=Area(x=467, y=507, width=360, height=435))
# │   }
# )

# %%
write_pos_rule(matched_layout, rule_templates)
# Out:
# "pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> tuo1.md' <76 460 0 0> @xn_md' <467 507 0 0>"

# %%
for i, layout in enumerate(all_layouts):
    print(write_pos_rule(layout, rule_templates))
# Out:
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> @sf_md' <24 460 0 0> tuo1.md' <180 460 0 0> @xn_md' <571 507 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> @sf_md' <24 460 0 0> pi1.md' <180 460 0 0> @xn_md' <460 671 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> @sf_md' <24 460 0 0> gou1.md' <180 460 0 0> @xn_md' <378 575 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> @sf_md' <24 460 0 0> ti1.md' <180 460 0 0> @xn_md' <425 590 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> @sf_md' <24 460 0 0> tiao3.md' <180 460 0 0> @xn_md' <465 536 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> @sf_md' <24 460 0 0> mo3.md' <180 460 0 0> @xn_md' <424 669 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> @sf_md' <24 460 0 0> da3.md' <180 460 0 0> @xn_md' <353 528 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> @sf_md' <24 460 0 0> zhai1.md' <180 460 0 0> @xn_md' <380 684 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> @sf_md' <24 460 0 0> mo3tiao3.md' <180 460 0 0> @xn_md' <479 669 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> @sf_md' <24 460 0 0> gou1ti1.md' <180 460 0 0> @xn_md' <441 692 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> @sf_md' <24 460 0 0> tuo1pi1.md' <180 460 0 0> @xn_md' <583 642 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> @sf_md' <24 460 0 0> da3zhai1.md' <180 460 0 0> @xn_md' <390 753 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> @sf_md' <24 460 0 0> tuo1.md' <180 460 0 0> @xn_md' <571 507 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> @sf_md' <24 460 0 0> pi1.md' <180 460 0 0> @xn_md' <460 671 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> @sf_md' <24 460 0 0> gou1.md' <180 460 0 0> @xn_md' <378 575 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> @sf_md' <24 460 0 0> ti1.md' <180 460 0 0> @xn_md' <425 590 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> @sf_md' <24 460 0 0> tiao3.md' <180 460 0 0> @xn_md' <465 536 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> @sf_md' <24 460 0 0> mo3.md' <180 460 0 0> @xn_md' <424 669 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> @sf_md' <24 460 0 0> da3.md' <180 460 0 0> @xn_md' <353 528 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> @sf_md' <24 460 0 0> zhai1.md' <180 460 0 0> @xn_md' <380 684 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> @sf_md' <24 460 0 0> mo3tiao3.md' <180 460 0 0> @xn_md' <479 669 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> @sf_md' <24 460 0 0> gou1ti1.md' <180 460 0 0> @xn_md' <441 692 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> @sf_md' <24 460 0 0> tuo1pi1.md' <180 460 0 0> @xn_md' <583 642 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> @sf_md' <24 460 0 0> da3zhai1.md' <180 460 0 0> @xn_md' <390 753 0 0>
# pos @hf_lg' <140 25 0 0> @sf_md' <24 460 0 0> tuo1.md' <180 460 0 0> @xn_md' <571 507 0 0>
# pos @hf_lg' <140 25 0 0> @sf_md' <24 460 0 0> pi1.md' <180 460 0 0> @xn_md' <460 671 0 0>
# pos @hf_lg' <140 25 0 0> @sf_md' <24 460 0 0> gou1.md' <180 460 0 0> @xn_md' <378 575 0 0>
# pos @hf_lg' <140 25 0 0> @sf_md' <24 460 0 0> ti1.md' <180 460 0 0> @xn_md' <425 590 0 0>
# pos @hf_lg' <140 25 0 0> @sf_md' <24 460 0 0> tiao3.md' <180 460 0 0> @xn_md' <465 536 0 0>
# pos @hf_lg' <140 25 0 0> @sf_md' <24 460 0 0> mo3.md' <180 460 0 0> @xn_md' <424 669 0 0>
# pos @hf_lg' <140 25 0 0> @sf_md' <24 460 0 0> da3.md' <180 460 0 0> @xn_md' <353 528 0 0>
# pos @hf_lg' <140 25 0 0> @sf_md' <24 460 0 0> zhai1.md' <180 460 0 0> @xn_md' <380 684 0 0>
# pos @hf_lg' <140 25 0 0> @sf_md' <24 460 0 0> mo3tiao3.md' <180 460 0 0> @xn_md' <479 669 0 0>
# pos @hf_lg' <140 25 0 0> @sf_md' <24 460 0 0> gou1ti1.md' <180 460 0 0> @xn_md' <441 692 0 0>
# pos @hf_lg' <140 25 0 0> @sf_md' <24 460 0 0> tuo1pi1.md' <180 460 0 0> @xn_md' <583 642 0 0>
# pos @hf_lg' <140 25 0 0> @sf_md' <24 460 0 0> da3zhai1.md' <180 460 0 0> @xn_md' <390 753 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> tuo1.md' <76 460 0 0> @xn_md' <467 507 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> pi1.md' <76 460 0 0> @xn_md' <356 671 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> gou1.md' <76 460 0 0> @xn_md' <274 575 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> ti1.md' <76 460 0 0> @xn_md' <321 590 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> tiao3.md' <76 460 0 0> @xn_md' <361 536 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> mo3.md' <76 460 0 0> @xn_md' <320 669 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> da3.md' <76 460 0 0> @xn_md' <249 528 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> zhai1.md' <76 460 0 0> @xn_md' <276 684 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> mo3tiao3.md' <76 460 0 0> @xn_md' <375 669 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> gou1ti1.md' <76 460 0 0> @xn_md' <337 692 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> tuo1pi1.md' <76 460 0 0> @xn_md' <479 642 0 0>
# pos @hf_md' <140 25 0 0> @hn_sm' <500 25 0 0> @hn_sm' <500 243 0 0> da3zhai1.md' <76 460 0 0> @xn_md' <286 753 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> tuo1.md' <76 460 0 0> @xn_md' <467 507 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> pi1.md' <76 460 0 0> @xn_md' <356 671 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> gou1.md' <76 460 0 0> @xn_md' <274 575 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> ti1.md' <76 460 0 0> @xn_md' <321 590 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> tiao3.md' <76 460 0 0> @xn_md' <361 536 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> mo3.md' <76 460 0 0> @xn_md' <320 669 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> da3.md' <76 460 0 0> @xn_md' <249 528 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> zhai1.md' <76 460 0 0> @xn_md' <276 684 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> mo3tiao3.md' <76 460 0 0> @xn_md' <375 669 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> gou1ti1.md' <76 460 0 0> @xn_md' <337 692 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> tuo1pi1.md' <76 460 0 0> @xn_md' <479 642 0 0>
# pos @hf_md' <140 25 0 0> @hn_md' <500 25 0 0> da3zhai1.md' <76 460 0 0> @xn_md' <286 753 0 0>
# pos @hf_lg' <140 25 0 0> tuo1.md' <76 460 0 0> @xn_md' <467 507 0 0>
# pos @hf_lg' <140 25 0 0> pi1.md' <76 460 0 0> @xn_md' <356 671 0 0>
# pos @hf_lg' <140 25 0 0> gou1.md' <76 460 0 0> @xn_md' <274 575 0 0>
# pos @hf_lg' <140 25 0 0> ti1.md' <76 460 0 0> @xn_md' <321 590 0 0>
# pos @hf_lg' <140 25 0 0> tiao3.md' <76 460 0 0> @xn_md' <361 536 0 0>
# pos @hf_lg' <140 25 0 0> mo3.md' <76 460 0 0> @xn_md' <320 669 0 0>
# pos @hf_lg' <140 25 0 0> da3.md' <76 460 0 0> @xn_md' <249 528 0 0>
# pos @hf_lg' <140 25 0 0> zhai1.md' <76 460 0 0> @xn_md' <276 684 0 0>
# pos @hf_lg' <140 25 0 0> mo3tiao3.md' <76 460 0 0> @xn_md' <375 669 0 0>
# pos @hf_lg' <140 25 0 0> gou1ti1.md' <76 460 0 0> @xn_md' <337 692 0 0>
# pos @hf_lg' <140 25 0 0> tuo1pi1.md' <76 460 0 0> @xn_md' <479 642 0 0>
# pos @hf_lg' <140 25 0 0> da3zhai1.md' <76 460 0 0> @xn_md' <286 753 0 0>

# %%
from jianzipu.feature import gen_rule_template

# %%
gen_rule_template()
# Out:
# {('xf', 'xn1', 'xn2'): '@xf_md @xn_sm @xn_sm',
#  ('xf', 'xn1'): '@xf_md @xn_md',
#  ('xf',): '@xf_md',
#  ('sf', 'xf', 'xn1', 'xn2'): '@sf_md @xf_md @xn_sm @xn_sm',
#  ('sf', 'xf', 'xn1'): '@sf_md @xf_md @xn_md',
#  ('sf', 'xf'): '@sf_md @xf_md',
#  ('sf',): '@sf_md',
#  ('hf', 'xf', 'xn1', 'xn2'): '@hf_md @xf_md @xn_sm @xn_sm',
#  ('hf', 'xf', 'xn1'): '@hf_md @xf_md @xn_md',
#  ('hf', 'xf'): '@hf_md @xf_md',
#  ('hf', 'sf', 'xf', 'xn1', 'xn2'): '@hf_md @sf_md @xf_md @xn_sm @xn_sm',
#  ('hf', 'sf', 'xf', 'xn1'): '@hf_md @sf_md @xf_md @xn_md',
#  ('hf', 'sf', 'xf'): '@hf_md @sf_md @xf_md',
#  ('hf', 'sf'): '@hf_md @sf_md',
#  ('hf', 'hn1', 'xf', 'xn1', 'xn2'): '@hf_md @hn_md @xf_md @xn_sm @xn_sm',
#  ('hf', 'hn1', 'xf', 'xn1'): '@hf_md @hn_md @xf_md @xn_md',
#  ('hf', 'hn1', 'xf'): '@hf_md @hn_md @xf_md',
#  ('hf',
#   'hn1',
#   'sf',
#   'xf',
#   'xn1',
#   'xn2'): '@hf_md @hn_md @sf_md @xf_md @xn_sm @xn_sm',
#  ('hf', 'hn1', 'sf', 'xf', 'xn1'): '@hf_md @hn_md @sf_md @xf_md @xn_md',
#  ('hf', 'hn1', 'sf', 'xf'): '@hf_md @hn_md @sf_md @xf_md',
#  ('hf', 'hn1', 'sf'): '@hf_md @hn_md @sf_md',
#  ('hf',
#   'hn1',
#   'hn2',
#   'xf',
#   'xn1',
#   'xn2'): '@hf_md @hn_sm @hn_sm @xf_md @xn_sm @xn_sm',
#  ('hf', 'hn1', 'hn2', 'xf', 'xn1'): '@hf_md @hn_sm @hn_sm @xf_md @xn_md',
#  ('hf', 'hn1', 'hn2', 'xf'): '@hf_md @hn_sm @hn_sm @xf_md',
#  ('hf',
#   'hn1',
#   'hn2',
#   'sf',
#   'xf',
#   'xn1',
#   'xn2'): '@hf_md @hn_sm @hn_sm @sf_md @xf_md @xn_sm @xn_sm',
#  ('hf',
#   'hn1',
#   'hn2',
#   'sf',
#   'xf',
#   'xn1'): '@hf_md @hn_sm @hn_sm @sf_md @xf_md @xn_md',
#  ('hf', 'hn1', 'hn2', 'sf', 'xf'): '@hf_md @hn_sm @hn_sm @sf_md @xf_md',
#  ('hf', 'hn1', 'hn2', 'sf'): '@hf_md @hn_sm @hn_sm @sf_md',
#  ('hf', 'hn1', 'hn2'): '@hf_md @hn_sm @hn_sm',
#  ('hf', 'hn1'): '@hf_md @hn_md',
#  ('hf',): '@hf_md'}

# %%
_, rule_templates = import_macros()

# %%
rule_templates
# Out:
# {('hf', 'xf', 'xn1'): ['@hf_md', '@xf_md', '@xn_md'],
#  ('hf', 'hn1', 'xf', 'xn1'): ['@hf_md', '@hn_md', '@xf_md', '@xn_md'],
#  ('hf', 'hn1', 'hn2', 'xf', 'xn1'): ['@hf_md',
#   '@hn_sm',
#   '@hn_sm',
#   '@xf_md',
#   '@xn_md'],
#  ('hf', 'sf', 'xf', 'xn1'): ['@hf_md', '@sf_md', '@xf_md', '@xn_md'],
#  ('hf', 'hn1', 'sf', 'xf', 'xn1'): ['@hf_md',
#   '@hn_md',
#   '@sf_md',
#   '@xf_md',
#   '@xn_md'],
#  ('hf', 'hn1', 'hn2', 'sf', 'xf', 'xn1'): ['@hf_md',
#   '@hn_sm',
#   '@hn_sm',
#   '@sf_md',
#   '@xf_md',
#   '@xn_md']}

# %%
gen_rule_template()
# Out:
# {'hf': '@hf_md',
#  'hf hn1': '@hf_md @hn_md',
#  'hf hn1 hn2': '@hf_md @hn_md @hn_md',
#  'hf hn1 hn2 sf xf': '@hf_md @hn_md @hn_md @sf_md @xf_md',
#  'hf hn1 hn2 sf xf xn1': '@hf_md @hn_md @hn_md @sf_md @xf_md @xn_md',
#  'hf hn1 hn2 sf xf xn1 xn2': '@hf_md @hn_md @hn_md @sf_md @xf_md @xn_md @xn_md',
#  'hf hn1 hn2 xf': '@hf_md @hn_md @hn_md @xf_md',
#  'hf hn1 hn2 xf xn1': '@hf_md @hn_md @hn_md @xf_md @xn_md',
#  'hf hn1 hn2 xf xn1 xn2': '@hf_md @hn_md @hn_md @xf_md @xn_md @xn_md',
#  'hf hn1 sf xf': '@hf_md @hn_md @sf_md @xf_md',
#  'hf hn1 sf xf xn1': '@hf_md @hn_md @sf_md @xf_md @xn_md',
#  'hf hn1 sf xf xn1 xn2': '@hf_md @hn_md @sf_md @xf_md @xn_md @xn_md',
#  'hf hn1 xf': '@hf_md @hn_md @xf_md',
#  'hf hn1 xf xn1': '@hf_md @hn_md @xf_md @xn_md',
#  'hf hn1 xf xn1 xn2': '@hf_md @hn_md @xf_md @xn_md @xn_md',
#  'hf sf xf': '@hf_md @sf_md @xf_md',
#  'hf sf xf xn1': '@hf_md @sf_md @xf_md @xn_md',
#  'hf sf xf xn1 xn2': '@hf_md @sf_md @xf_md @xn_md @xn_md',
#  'hf xf': '@hf_md @xf_md',
#  'hf xf xn1': '@hf_md @xf_md @xn_md',
#  'hf xf xn1 xn2': '@hf_md @xf_md @xn_md @xn_md',
#  'sf xf': '@sf_md @xf_md',
#  'sf xf xn1': '@sf_md @xf_md @xn_md',
#  'sf xf xn1 xn2': '@sf_md @xf_md @xn_md @xn_md',
#  'xf': '@xf_md',
#  'xf xn1': '@xf_md @xn_md',
#  'xf xn1 xn2': '@xf_md @xn_md @xn_md'}
