# %% [markdown]
# # 解析用法一览 Parse class showcase

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## 解析正写法 parse orthodox reading

# %%
l = [
    "大指七徽六分勾三弦",
    "跪指五徽八分挑六弦",
    "名指一徽九分注挑二弦",
    "食指十二徽半绰抹挑四弦",
    "中指徽外勾剔七弦",
    "中指徽外历二弦三弦",
    "散音历二弦三弦",
    "大指七徽六分掩",
    "名指七徽六分搯起",
    "打圆",
    "不动",
    "推出",
    "滚拂",
]

# %%
from jianzipu.parser import parse
from rich.pretty import pprint as pp

for i in l:
    tree = parse(i, "ortho")
    pp(tree)
# Out:
# ParseNode(
# │   tag='SF',
# │   children={
# │   │   'hfp': ParseNode(
# │   │   │   tag='hfp',
# │   │   │   children={
# │   │   │   │   'hf': ParseNode(tag='hf', name='大'),
# │   │   │   │   'hn1': ParseNode(tag='hn1', name='七'),
# │   │   │   │   'hn2': ParseNode(tag='hn2', name='六')
# │   │   │   }
# │   │   ),
# │   │   'xfp': ParseNode(
# │   │   │   tag='xfp',
# │   │   │   children={'xf': ParseNode(tag='xf', name='勾'), 'xn1': ParseNode(tag='xn1', name='三')}
# │   │   )
# │   }
# )
# ParseNode(
# │   tag='SF',
# │   children={
# │   │   'hfp': ParseNode(
# │   │   │   tag='hfp',
# │   │   │   children={
# │   │   │   │   'hf': ParseNode(tag='hf', name='跪'),
# │   │   │   │   'hn1': ParseNode(tag='hn1', name='五'),
# │   │   │   │   'hn2': ParseNode(tag='hn2', name='八')
# │   │   │   }
# │   │   ),
# │   │   'xfp': ParseNode(
# │   │   │   tag='xfp',
# │   │   │   children={'xf': ParseNode(tag='xf', name='挑'), 'xn1': ParseNode(tag='xn1', name='六')}
# │   │   )
# │   }
# )
# ...

# %% [markdown]
# ## 解析简写法 parse abbreviation reading

# %%
l = [
    "大一六勾三",
    "大二剔四",
    "跪三七抹五",
    "跪四挑六",
    "名五八注托七",
    "名六注擘一",
    "中七打二",
    "中八九摘三",
    "食十绰打四",
    "食外绰打五",
    "中外摘六",
    "中外历二三",
    "散历二三",
    "勾三",
    "大七六掩",
    "名七六搯起",
    "名十二搯起",
    "名十二三搯起",
    "名十三搯起",
    "名十三抹挑三",
    "名十三勾剔三",
    "撮大七七三散四",
    "撮大七七注三散四",
]

# %%
from jianzipu.parser import parse

for i in l:
    tree = parse(i, form="abbr")
    pp(tree)
    # break
# Out:
# ParseNode(
# │   tag='SF',
# │   children={
# │   │   'hfp': ParseNode(
# │   │   │   tag='hfp',
# │   │   │   children={
# │   │   │   │   'hf': ParseNode(tag='hf', name='大'),
# │   │   │   │   'hn1': ParseNode(tag='hn1', name='一'),
# │   │   │   │   'hn2': ParseNode(tag='hn2', name='六')
# │   │   │   }
# │   │   ),
# │   │   'xfp': ParseNode(
# │   │   │   tag='xfp',
# │   │   │   children={'xf': ParseNode(tag='xf', name='勾'), 'xn1': ParseNode(tag='xn1', name='三')}
# │   │   )
# │   }
# )
# ParseNode(
# │   tag='SF',
# │   children={
# │   │   'hfp': ParseNode(
# │   │   │   tag='hfp',
# │   │   │   children={'hf': ParseNode(tag='hf', name='大'), 'hn1': ParseNode(tag='hn1', name='二')}
# │   │   ),
# │   │   'xfp': ParseNode(
# │   │   │   tag='xfp',
# │   │   │   children={'xf': ParseNode(tag='xf', name='剔'), 'xn1': ParseNode(tag='xn1', name='四')}
# │   │   )
# │   }
# )
# ParseNode(
# │   tag='SF',
# │   children={
# │   │   'hfp': ParseNode(
# │   │   │   tag='hfp',
# ...

# %% [markdown]
# ## 解析树转换为读法 parse tree to string

# %%
tree.to_string(form="ortho")
# Out:
# '撮大指七徽七分注三弦散音四弦'

# %%
tree.to_string(form="abbr")
# Out:
# '撮大七七注三散四'
