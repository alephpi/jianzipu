# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## 解析正写法 parse orthodox reading

# %%
l = [
    "大指七徽六分勾三弦",
    "跪指五徽八分挑六弦",
    "名指一徽九分注挑二弦",
    "食指十二徽半绰抹挑四弦",
    "中指徽外勾剔七弦",
    "中指徽外历二弦三弦",
    "散音历二弦三弦",
    "大指七徽六分掩",
    "名指七徽六分搯起",
    "打圆",
    "不动",
    "推出",
    "滚拂",
]

# %%
from jianzipu.parser import parse
import pprint

pp = pprint.PrettyPrinter(indent=2)
for i in l:
    tree = parse(i, "ortho")
    pp.pprint(tree)
# Out:
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='大',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='七',
#                                                                   children={}),
#                                                  'hn2': ParseNode(tag='hn2',
#                                                                   name='六',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='勾',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='三',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='跪',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='五',
#                                                                   children={}),
#                                                  'hn2': ParseNode(tag='hn2',
#                                                                   name='八',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='挑',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='六',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='名',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='一',
#                                                                   children={}),
#                                                  'hn2': ParseNode(tag='hn2',
#                                                                   name='九',
#                                                                   children={})}),
#                      'sf': ParseNode(tag='sf', name='注', children={}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='挑',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='二',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='食',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='十二',
#                                                                   children={}),
#                                                  'hn2': ParseNode(tag='hn2',
#                                                                   name='半',
#                                                                   children={})}),
#                      'sf': ParseNode(tag='sf', name='绰', children={}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='抹挑',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='四',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='中',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='外',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='勾剔',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='七',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='中',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='外',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='历',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='二',
#                                                                   children={}),
#                                                  'xn2': ParseNode(tag='xn2',
#                                                                   name='三',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='散',
#                                                                  children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='历',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='二',
#                                                                   children={}),
#                                                  'xn2': ParseNode(tag='xn2',
#                                                                   name='三',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='大',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='七',
#                                                                   children={}),
#                                                  'hn2': ParseNode(tag='hn2',
#                                                                   name='六',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='掩',
#                                                                  children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='名',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='七',
#                                                                   children={}),
#                                                  'hn2': ParseNode(tag='hn2',
#                                                                   name='六',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='搯起',
#                                                                  children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='打圆',
#                                                                  children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='不动',
#                                                                  children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='推出',
#                                                                  children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='滚拂',
#                                                                  children={})})})

# %% [markdown]
# ## 解析简写法 parse abbreviation reading

# %%
l = [
    "大一六勾三",
    "大二剔四",
    "跪三七抹五",
    "跪四挑六",
    "名五八注托七",
    "名六注擘一",
    "中七打二",
    "中八九摘三",
    "食十绰打四",
    "食外绰打五",
    "中外摘六",
    "中外历二三",
    "散历二三",
    "勾三",
    "大七六掩",
    "名七六搯起",
    "名十二搯起",
    "名十二三搯起",
    "名十三搯起",
    "名十三抹挑三",
    "名十三勾剔三",
    "撮大七七三散四",
    "撮大七七注三散四",
]

# %%
from jianzipu.parser import parse

for i in l:
    tree = parse(i, form="abbr")
    pp.pprint(tree)
    # break
# Out:
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='大',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='一',
#                                                                   children={}),
#                                                  'hn2': ParseNode(tag='hn2',
#                                                                   name='六',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='勾',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='三',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='大',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='二',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='剔',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='四',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='跪',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='三',
#                                                                   children={}),
#                                                  'hn2': ParseNode(tag='hn2',
#                                                                   name='七',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='抹',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='五',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='跪',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='四',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='挑',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='六',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='名',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='五',
#                                                                   children={}),
#                                                  'hn2': ParseNode(tag='hn2',
#                                                                   name='八',
#                                                                   children={})}),
#                      'sf': ParseNode(tag='sf', name='注', children={}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='托',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='七',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='名',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='六',
#                                                                   children={})}),
#                      'sf': ParseNode(tag='sf', name='注', children={}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='擘',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='一',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='中',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='七',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='打',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='二',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='中',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='八',
#                                                                   children={}),
#                                                  'hn2': ParseNode(tag='hn2',
#                                                                   name='九',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='摘',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='三',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='食',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='十',
#                                                                   children={})}),
#                      'sf': ParseNode(tag='sf', name='绰', children={}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='打',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='四',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='食',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='外',
#                                                                   children={})}),
#                      'sf': ParseNode(tag='sf', name='绰', children={}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='打',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='五',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='中',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='外',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='摘',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='六',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='中',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='外',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='历',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='二',
#                                                                   children={}),
#                                                  'xn2': ParseNode(tag='xn2',
#                                                                   name='三',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='散',
#                                                                  children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='历',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='二',
#                                                                   children={}),
#                                                  'xn2': ParseNode(tag='xn2',
#                                                                   name='三',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='勾',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='三',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='大',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='七',
#                                                                   children={}),
#                                                  'hn2': ParseNode(tag='hn2',
#                                                                   name='六',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='掩',
#                                                                  children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='名',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='七',
#                                                                   children={}),
#                                                  'hn2': ParseNode(tag='hn2',
#                                                                   name='六',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='搯起',
#                                                                  children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='名',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='十二',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='搯起',
#                                                                  children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='名',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='十二',
#                                                                   children={}),
#                                                  'hn2': ParseNode(tag='hn2',
#                                                                   name='三',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='搯起',
#                                                                  children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='名',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='十三',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='搯起',
#                                                                  children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='名',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='十三',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='抹挑',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='三',
#                                                                   children={})})})
# ParseNode(tag='SF',
#           name='',
#           children={ 'hfp': ParseNode(tag='hfp',
#                                       name='',
#                                       children={ 'hf': ParseNode(tag='hf',
#                                                                  name='名',
#                                                                  children={}),
#                                                  'hn1': ParseNode(tag='hn1',
#                                                                   name='十三',
#                                                                   children={})}),
#                      'xfp': ParseNode(tag='xfp',
#                                       name='',
#                                       children={ 'xf': ParseNode(tag='xf',
#                                                                  name='勾剔',
#                                                                  children={}),
#                                                  'xn1': ParseNode(tag='xn1',
#                                                                   name='三',
#                                                                   children={})})})
# ParseNode(tag='CF',
#           name='',
#           children={ 'cf': ParseNode(tag='cf', name='撮', children={}),
#                      'lsp': ParseNode(tag='lsp',
#                                       name='',
#                                       children={ 'hfp': ParseNode(tag='hfp',
#                                                                   name='',
#                                                                   children={ 'hf': ParseNode(tag='hf',
#                                                                                              name='大',
#                                                                                              children={ }),
#                                                                              'hn1': ParseNode(tag='hn1',
#                                                                                               name='七',
#                                                                                               children={ }),
#                                                                              'hn2': ParseNode(tag='hn2',
#                                                                                               name='七',
#                                                                                               children={ })}),
#                                                  'xfp': ParseNode(tag='xfp',
#                                                                   name='',
#                                                                   children={ 'xn1': ParseNode(tag='xn1',
#                                                                                               name='三',
#                                                                                               children={ })})}),
#                      'rsp': ParseNode(tag='rsp',
#                                       name='',
#                                       children={ 'hfp': ParseNode(tag='hfp',
#                                                                   name='',
#                                                                   children={ 'hf': ParseNode(tag='hf',
#                                                                                              name='散',
#                                                                                              children={ })}),
#                                                  'xfp': ParseNode(tag='xfp',
#                                                                   name='',
#                                                                   children={ 'xn1': ParseNode(tag='xn1',
#                                                                                               name='四',
#                                                                                               children={ })})})})
# ParseNode(tag='CF',
#           name='',
#           children={ 'cf': ParseNode(tag='cf', name='撮', children={}),
#                      'lsp': ParseNode(tag='lsp',
#                                       name='',
#                                       children={ 'hfp': ParseNode(tag='hfp',
#                                                                   name='',
#                                                                   children={ 'hf': ParseNode(tag='hf',
#                                                                                              name='大',
#                                                                                              children={ }),
#                                                                              'hn1': ParseNode(tag='hn1',
#                                                                                               name='七',
#                                                                                               children={ }),
#                                                                              'hn2': ParseNode(tag='hn2',
#                                                                                               name='七',
#                                                                                               children={ })}),
#                                                  'sf': ParseNode(tag='sf',
#                                                                  name='注',
#                                                                  children={}),
#                                                  'xfp': ParseNode(tag='xfp',
#                                                                   name='',
#                                                                   children={ 'xn1': ParseNode(tag='xn1',
#                                                                                               name='三',
#                                                                                               children={ })})}),
#                      'rsp': ParseNode(tag='rsp',
#                                       name='',
#                                       children={ 'hfp': ParseNode(tag='hfp',
#                                                                   name='',
#                                                                   children={ 'hf': ParseNode(tag='hf',
#                                                                                              name='散',
#                                                                                              children={ })}),
#                                                  'xfp': ParseNode(tag='xfp',
#                                                                   name='',
#                                                                   children={ 'xn1': ParseNode(tag='xn1',
#                                                                                               name='四',
#                                                                                               children={ })})})})

# %% [markdown]
# ## 解析树转换为读法 parse tree to string

# %%
tree.to_string(form="ortho")
# Out:
# '撮大指七徽七分注三弦散音四弦'

# %%
tree.to_string(form="abbr")
# Out:
# '撮大七七注三散四'
