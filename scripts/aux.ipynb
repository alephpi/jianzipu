# %%
from jianzipu.constants import GLYPHS

# %%
xf = GLYPHS.query("GlyphTag=='xf'").GlyphName.tolist()
n = GLYPHS.query("GlyphTag=='n'").GlyphName.tolist()

# %%
print([xf + ".md" for xf in xf])
# Out:
# ['tuo1.md', 'pi1.md', 'mo3.md', 'tiao3.md', 'gou1.md', 'ti1.md', 'da3.md', 'zhai1.md', 'tuo1pi1.md', 'mo3tiao3.md', 'gou1ti1.md', 'da3zhai1.md', 'li4.md', 'juan1.md', 'lun2.md', 'ban4lun2.md', 'suo3.md', 'chang2suo3.md', 'ru2yi1.md', 'fu2.md', 'ru2yi1sheng1.md', 'gun3.md', 'fo2.md', 'zhi4.md', 'gun3fo2.md', 'quan2fu2.md', 'la4fu2.md', 'da3yuan2.md', 'tao1qi3.md', 'zhua1qi3.md', 'dai4qi3.md', 'yan3.md', 'xu1yan3.md', 'tui1chu1.md', 'bu4dong4.md']

# %%
print([n + ".sm" for n in n])
# Out:
# ['yi1.sm', 'er4.sm', 'san1.sm', 'si4.sm', 'wu3.sm', 'liu4.sm', 'qi1.sm', 'ba1.sm', 'jiu3.sm', 'shii2.sm', 'shi2yi1.sm', 'shi2er4.sm', 'shi2san1.sm', 'wai4.sm', 'ban4.sm']

# %%
print([n + ".md" for n in n])
# Out:
# ['yi1.md', 'er4.md', 'san1.md', 'si4.md', 'wu3.md', 'liu4.md', 'qi1.md', 'ba1.md', 'jiu3.md', 'shii2.md', 'shi2yi1.md', 'shi2er4.md', 'shi2san1.md', 'wai4.md', 'ban4.md']
